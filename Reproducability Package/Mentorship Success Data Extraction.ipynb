# %%
# %pip install pymongo
# %pip install pandas
# %pip install geopy
# %pip install folium
# %pip install seaborn
# %pip install matplotlib
# %pip install -U scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
PATH = r"~/Downloads/success_mentor.csv"
PATH2 = r"~/Downloads/success_mentor22.csv"
smentors2 = pd.read_csv(PATH, skip_blank_lines=False)
smentors22 = pd.read_csv(PATH2, skip_blank_lines=False)
frames = [smentors2, smentors22]
smentors2 = pd.concat(frames)
smentors2
# Out:
#                login         mentee_name      owner_name            repo_name  \
# 0         Riken-Shah          Riken Shah           zulip                zulip
# 1           pchengma        Pengcheng Ma          apache  incubator-eventmesh
# 2              ffaf1                 NaN         haskell                cabal
# 3              ffaf1                 NaN         haskell                cabal
# 4        Sov-trotter         Arsh Sharma  JuliaAnimators             Javis.jl
# ..               ...                 ...             ...                  ...
# 110      Tarun-Arora         Tarun Arora     CCExtractor      sample-platform
# 111    preetvadaliya   Preet P. Vadaliya         mit-cml  appinventor-sources
# 112    preetvadaliya   Preet P. Vadaliya         mit-cml  appinventor-sources
# 113    preetvadaliya   Preet P. Vadaliya         mit-cml  appinventor-sources
# 114  ItsAdityaKSingh  Aditya Kumar Singh     CCExtractor               beacon
#
# ...

# %%
import pandas as pd
PATH = r"~/Downloads/unsuccess_mentor.csv"
PATH2 = r"~/Downloads/unsuccess_mentor22.csv"
umentors2 = pd.read_csv(PATH, skip_blank_lines=False)
umentors22 = pd.read_csv(PATH2, skip_blank_lines=False)
frames = [umentors2, umentors22]
umentors2 = pd.concat(frames)
umentors2
# Out:
#               login     mentee_name           owner_name            repo_name  \
# 0      Himanshu2107   Himanshu Garg              mit-cml  appinventor-sources
# 1   SHIVAJIKUMAR007         SHIVAJI  react-native-webrtc  react-native-webrtc
# 2   SHIVAJIKUMAR007         SHIVAJI  react-native-webrtc  react-native-webrtc
# 3            Bhu1-V        Pun1sher          godotengine                godot
# 4            Bhu1-V        Pun1sher          godotengine                godot
# ..              ...             ...                  ...                  ...
# 83  ArbitRandomUser            john       JuliaAnimators             Javis.jl
# 84         mabelbot           Mabel               chaoss            community
# 85         mabelbot           Mabel               chaoss            community
# 86   techiepriyansh  Priyansh Rathi          godotengine                godot
# 87   techiepriyansh  Priyansh Rathi          godotengine                godot
#
#     pair_id  GSoC  mentor_login
# ...

# %%
import pandas as pd
PATH = r"~/Downloads/success.csv"
PATH2 = r"~/Downloads/success22.csv"
smentees = pd.read_csv(PATH, skip_blank_lines=False)
smentees22 = pd.read_csv(PATH2, skip_blank_lines=False)
smentees = smentees.rename(columns={"mentee_name": "mentee_login"})
smentees = smentees.drop_duplicates(subset=['mentee_login'])
smentees22 = smentees22.rename(columns={"mentee_name": "mentee_login"})
smentees22 = smentees22.drop_duplicates(subset=['mentee_login'])
frames = [smentees, smentees22]
smentees = pd.concat(frames)
smentees
# Out:
#                 mentee_login  number_of_pulls
# 0                 iuliadmtru               60
# 1                  arsalan0c               30
# 2           NishantSinghal19               26
# 3   personalizedrefrigerator               26
# 4                      ffaf1               25
# ..                       ...              ...
# 69                  kubaneko                1
# 70         abdelrahmanmagdii                1
# 71                 alive2020                1
# 72                anutosh491                1
# 73                  bryan506                1
#
# [129 rows x 2 columns]

# %%
import pandas as pd
PATH = r"~/Downloads/unsuccessful.csv"
PATH2 = r"~/Downloads/unsuccessful22.csv"
umentees = pd.read_csv(PATH, skip_blank_lines=False)
umentees = umentees.rename(columns={"login": "mentee_login"})
umentees22 = pd.read_csv(PATH2, skip_blank_lines=False)
umentees22 = umentees22.rename(columns={"login": "mentee_login"})
frames = [umentees, umentees22]
umentees = pd.concat(frames)
umentees
# Out:
#     index     mentee_login  GSoC
# 0     1.0           Bhu1-V  2021
# 1    14.0           jul1u5  2021
# 2    25.0          r0hit05  2021
# 3    36.0    AnujSinghal12  2021
# 4    39.0       Aksh-Konda  2021
# ..    ...              ...   ...
# 38    NaN       lukekang98  2022
# 39    NaN         Hrushi20  2022
# 40    NaN      chenyanlann  2022
# 41    NaN       ericluoliu  2022
# 42    NaN  ArbitRandomUser  2022
#
# [209 rows x 3 columns]

# %%
import pandas as pd
PATH = r"/Users/akshajsrinivasan/Desktop/UBCO/4TH YEAR/SUMMER/TERM2/DIRECTED_STUDIES_COURSE/Data.Users.xlsx"
users = pd.read_excel(PATH)
users
# Out:
#                           _id              login        id  \
# 0    63bf62bc2ff787e5d7eb85ec           ewpatton   1331253
# 1    63c048eee5a00d9932c67337       tmoldovan8x8  62697631
# 2    63c048efe5a00d9932c67338             saghul    317464
# 3    63be17be443439f227312a7a             KoBeWi   2223172
# 4    63be17be443439f227312a7b            Calinou    180032
# ..                        ...                ...       ...
# 628  63b38bd0633b8bed413fb60c  devarsh-mavani-19  55136047
# 629  63bfbb88c91c8d6c6ab4281f        Tarun-Arora  78356489
# 630  63b3a2813583662c28eeb944      preetvadaliya  80121827
# 631  63b38a3e56adab3ffd7680ba     techiepriyansh  26199781
# 632  63bfbc37be4bec0503c05389    ItsAdityaKSingh  69353350
#
#                   node_id                                         avatar_url  \
# 0    MDQ6VXNlcjEzMzEyNTM=  https://avatars.githubusercontent.com/u/133125...
# 1    MDQ6VXNlcjYyNjk3NjMx  https://avatars.githubusercontent.com/u/626976...
# ...

# %%
import pandas as pd
PATH = r"/Users/akshajsrinivasan/Desktop/UBCO/4TH YEAR/SUMMER/TERM2/DIRECTED_STUDIES_COURSE/Data.Comments.xlsx"
comments = pd.read_excel(PATH)
comments.dropna(how='all', axis=1, inplace=True)
comments
# Out:
#                             _id  \
# 0      6417d416cbe9dbf73267d056
# 1      6417d418cbe9dbf73267d05a
# 2      6417d419cbe9dbf73267d05d
# 3      6417d419cbe9dbf73267d060
# 4      6417d41acbe9dbf73267d065
# ...                         ...
# 13731  6417e3709c61aa4dd0bf798f
# 13732  6417e3739c61aa4dd0bf7996
# 13733  6417e3739c61aa4dd0bf7997
# 13734  6417e3769c61aa4dd0bf799a
# 13735  6417e3769c61aa4dd0bf799c
#
#                                                      url  \
# 0      https://api.github.com/repos/mit-cml/appinvent...
# 1      https://api.github.com/repos/mit-cml/appinvent...
# 2      https://api.github.com/repos/mit-cml/appinvent...
# 3      https://api.github.com/repos/mit-cml/appinvent...
# 4      https://api.github.com/repos/mit-cml/appinvent...
# ...                                                  ...
# 13731  https://api.github.com/repos/CCExtractor/beaco...
# 13732  https://api.github.com/repos/CCExtractor/beaco...
# ...

# %%
import pandas as pd
PATH = r"/Users/akshajsrinivasan/Desktop/UBCO/4TH YEAR/SUMMER/TERM2/DIRECTED_STUDIES_COURSE/Data.Pulls.xlsx"
pulls = pd.read_excel(PATH)
pulls.dropna(how='all', axis=1, inplace=True)
pulls
# Out:
#                            _id  \
# 0     6417db48293807e5b39873d7
# 1     6417db47293807e5b39873d5
# 2     6417db49293807e5b39873d9
# 3     6417db49293807e5b39873e0
# 4     6417db49293807e5b39873e1
# ...                        ...
# 3282  6417d2d3a658fc9ea490d8d4
# 3283  6417d2d3a658fc9ea490d8d5
# 3284  6417d311a658fc9ea490d8d6
# 3285  6417d311a658fc9ea490d8d9
# 3286  6417d311a658fc9ea490d8de
#
#                                                     url  \
# 0     https://api.github.com/repos/zulip/zulip/issue...
# 1     https://api.github.com/repos/react-native-webr...
# 2     https://api.github.com/repos/zulip/zulip/issue...
# 3     https://api.github.com/repos/zulip/zulip/issue...
# 4     https://api.github.com/repos/zulip/zulip/issue...
# ...                                                 ...
# 3282  https://api.github.com/repos/scrapy/scrapy/iss...
# 3283  https://api.github.com/repos/scrapy/scrapy/iss...
# 3284  https://api.github.com/repos/postmanlabs/newma...
# ...

# %%
smentors = smentors2.drop_duplicates()
smentors = smentors.drop(['login', 'mentee_name', 'owner_name', 'repo_name', 'GSoC'], axis=1)
smentors
# Out:
#      pair_id         mentor_login
# 0        2.1            timabbott
# 1        4.1              xwm1992
# 2        7.1          andreasabel
# 3        7.1            jaspervdj
# 4        9.0              Wikunia
# ..       ...                  ...
# 104    111.1            Pearl1594
# 105    111.1  harikrishna-patnala
# 106    116.1            roman-r-m
# 107    117.1            michaelpj
# 108    118.1               jisqyv
#
# [156 rows x 2 columns]

# %%
umentors = umentors2.drop_duplicates()
umentors = umentors.drop(['login', 'mentee_name', 'owner_name', 'repo_name', 'GSoC'], axis=1)
umentors
# Out:
#      pair_id  mentor_login
# 0        1.0      ewpatton
# 1        1.1        saghul
# 2        1.1  tmoldovan8x8
# 3        2.0       Calinou
# 4        2.0         groud
# ..       ...           ...
# 304    116.1     roman-r-m
# 305    117.1     michaelpj
# 306    118.1        jisqyv
# 307    121.1      clayjohn
# 308    121.1         JFonS
#
# [299 rows x 2 columns]

# %%
usersMentors1 = users.loc[users['mentor'] == True]
usersMentors1 = usersMentors1.rename(columns={"login": "mentor_login"})
userMentors = usersMentors1.drop_duplicates(subset=['mentor_login','id','pair_id','node_id', 'repo_name', 'GSoC'])
userMentors
# Out:
#                           _id   mentor_login        id               node_id  \
# 0    63bf62bc2ff787e5d7eb85ec       ewpatton   1331253  MDQ6VXNlcjEzMzEyNTM=
# 1    63c048eee5a00d9932c67337   tmoldovan8x8  62697631  MDQ6VXNlcjYyNjk3NjMx
# 2    63c048efe5a00d9932c67338         saghul    317464  MDQ6VXNlcjMxNzQ2NA==
# 3    63be17be443439f227312a7a         KoBeWi   2223172  MDQ6VXNlcjIyMjMxNzI=
# 4    63be17be443439f227312a7b        Calinou    180032  MDQ6VXNlcjE4MDAzMg==
# ..                        ...            ...       ...                   ...
# 403  63b3a298159f5879c18fa9ec  preetvadaliya  80121827  MDQ6VXNlcjgwMTIxODI3
# 404  63b3a299159f5879c18fa9ed       ewpatton   1331253  MDQ6VXNlcjEzMzEyNTM=
# 406  63b38a3f56adab3ffd7680bb       clayjohn  16521339  MDQ6VXNlcjE2NTIxMzM5
# 407  63b38a4056adab3ffd7680bc          JFonS   4402304  MDQ6VXNlcjQ0MDIzMDQ=
# 408  63bfbc37be4bec0503c0538a         nb9960  63557873  MDQ6VXNlcjYzNTU3ODcz
#
# ...

# %%
usersMentees1 = users.loc[users['mentor'] == False]
usersMentees1 = usersMentees1.rename(columns={"login": "mentee_login"})
userMentees = usersMentees1.drop_duplicates(subset=['mentee_login','id','pair_id','node_id', 'repo_name', 'GSoC'])
userMentees
# Out:
#                           _id       mentee_login        id  \
# 409  63bf62bb2ff787e5d7eb85eb       Himanshu2107  53406453
# 410  63c048eee5a00d9932c67336    SHIVAJIKUMAR007  55244409
# 411  63be17bd443439f227312a79             Bhu1-V  70578657
# 412  63b3ac46e522528f6fdafbb7         Riken-Shah  63820270
# 413  63bfb0a4750d32adb2b2309c              abd99  30566863
# ..                        ...                ...       ...
# 628  63b38bd0633b8bed413fb60c  devarsh-mavani-19  55136047
# 629  63bfbb88c91c8d6c6ab4281f        Tarun-Arora  78356489
# 630  63b3a2813583662c28eeb944      preetvadaliya  80121827
# 631  63b38a3e56adab3ffd7680ba     techiepriyansh  26199781
# 632  63bfbc37be4bec0503c05389    ItsAdityaKSingh  69353350
#
#                   node_id                                         avatar_url  \
# 409  MDQ6VXNlcjUzNDA2NDUz  https://avatars.githubusercontent.com/u/534064...
# 410  MDQ6VXNlcjU1MjQ0NDA5  https://avatars.githubusercontent.com/u/552444...
# ...

# %%
umentees
# Out:
#     index     mentee_login  GSoC
# 0     1.0           Bhu1-V  2021
# 1    14.0           jul1u5  2021
# 2    25.0          r0hit05  2021
# 3    36.0    AnujSinghal12  2021
# 4    39.0       Aksh-Konda  2021
# ..    ...              ...   ...
# 38    NaN       lukekang98  2022
# 39    NaN         Hrushi20  2022
# 40    NaN      chenyanlann  2022
# 41    NaN       ericluoliu  2022
# 42    NaN  ArbitRandomUser  2022
#
# [209 rows x 3 columns]

# %%
smentees
# Out:
#                 mentee_login  number_of_pulls
# 0                 iuliadmtru               60
# 1                  arsalan0c               30
# 2           NishantSinghal19               26
# 3   personalizedrefrigerator               26
# 4                      ffaf1               25
# ..                       ...              ...
# 69                  kubaneko                1
# 70         abdelrahmanmagdii                1
# 71                 alive2020                1
# 72                anutosh491                1
# 73                  bryan506                1
#
# [129 rows x 2 columns]

# %%
#Determining successful mentees from data
import numpy as np
userMentees = pd.merge(userMentees, smentees, on=['mentee_login'], how='left', indicator='exists')
userMentees['exists'] = np.where(userMentees.exists == 'both', True, False)
userMentees = userMentees.rename(columns={"exists": "Success"})
userMentees = userMentees.drop('number_of_pulls', axis=1)
filepath = '/Users/akshajsrinivasan/Desktop/ddout.csv'
userMentees.to_csv(filepath)

# %%
#Determining successful mentors from data
import numpy as np
userMentors = pd.merge(userMentors, smentors, on=['mentor_login', 'pair_id'], how='left', indicator='exists')
userMentors['exists'] = np.where(userMentors.exists == 'both', True, False)
userMentors = userMentors.rename(columns={"exists": "Success"})
filepath = '/Users/akshajsrinivasan/Desktop/ddout2.csv'
userMentors.to_csv(filepath)

# %%
pulls['body']
# Out:
# 0       Currently, `drafts.ts` suffers from a non-dete...
# 1       this is the video effect registry\r\n\r\nto cr...
# 2       We were getting the `undefined` error when acc...
# 3       <!-- Describe your pull request here.-->\r\nIt...
# 4       Earlier mid word parts matching with the searc...
#                               ...
# 3282                                                  NaN
# 3283    changed ie. -> i.e.(spelling error) on lines 6...
# 3284                                                  NaN
# 3285                                                  NaN
# 3286                                                  NaN
# Name: body, Length: 3287, dtype: object

# %%
comments['body']
# Out:
# 0                         @AppInventorWorkerBee ok to test
# 1                 Can one of the admins verify this patch?
# 2        @Himanshu2107 Since you're updating an API rel...
# 3        @Himanshu2107 Yes, that's correct.  `YOUNG_AND...
# 4        @Himanshu2107 You'll want to revert the merge ...
#                                ...
# 13731                                        Done @nb9960!
# 13732    > iOS setup is still incomplete, i.e, API key ...
# 13733                   Thanks for the PR, merged! :tada:
# 13734    Both LandMark and Location fromJson method is ...
# 13735    > There shouldn't be a redundancy as there are...
# Name: body, Length: 13736, dtype: object

# %%
userMentees = userMentees.rename(columns={"mentee_login": "login"})
userMentees
# Out:
#                           _id            login        id  \
# 0    63bf62bb2ff787e5d7eb85eb     Himanshu2107  53406453
# 1    63c048eee5a00d9932c67336  SHIVAJIKUMAR007  55244409
# 2    63be17bd443439f227312a79           Bhu1-V  70578657
# 3    63b3ac46e522528f6fdafbb7       Riken-Shah  63820270
# 4    63b3ac46e522528f6fdafbb7       Riken-Shah  63820270
# ..                        ...              ...       ...
# 256  63b3a2813583662c28eeb944    preetvadaliya  80121827
# 257  63b3a2813583662c28eeb944    preetvadaliya  80121827
# 258  63b38a3e56adab3ffd7680ba   techiepriyansh  26199781
# 259  63bfbc37be4bec0503c05389  ItsAdityaKSingh  69353350
# 260  63bfbc37be4bec0503c05389  ItsAdityaKSingh  69353350
#
#                   node_id                                         avatar_url  \
# 0    MDQ6VXNlcjUzNDA2NDUz  https://avatars.githubusercontent.com/u/534064...
# 1    MDQ6VXNlcjU1MjQ0NDA5  https://avatars.githubusercontent.com/u/552444...
# ...

# %%
userMentors = userMentors.rename(columns={"mentor_login": "login"})
userMentors
# Out:
#                           _id          login        id               node_id  \
# 0    63bf62bc2ff787e5d7eb85ec       ewpatton   1331253  MDQ6VXNlcjEzMzEyNTM=
# 1    63c048eee5a00d9932c67337   tmoldovan8x8  62697631  MDQ6VXNlcjYyNjk3NjMx
# 2    63c048efe5a00d9932c67338         saghul    317464  MDQ6VXNlcjMxNzQ2NA==
# 3    63be17be443439f227312a7a         KoBeWi   2223172  MDQ6VXNlcjIyMjMxNzI=
# 4    63be17be443439f227312a7b        Calinou    180032  MDQ6VXNlcjE4MDAzMg==
# ..                        ...            ...       ...                   ...
# 391  63b3a298159f5879c18fa9ec  preetvadaliya  80121827  MDQ6VXNlcjgwMTIxODI3
# 392  63b3a299159f5879c18fa9ed       ewpatton   1331253  MDQ6VXNlcjEzMzEyNTM=
# 393  63b38a3f56adab3ffd7680bb       clayjohn  16521339  MDQ6VXNlcjE2NTIxMzM5
# 394  63b38a4056adab3ffd7680bc          JFonS   4402304  MDQ6VXNlcjQ0MDIzMDQ=
# 395  63bfbc37be4bec0503c0538a         nb9960  63557873  MDQ6VXNlcjYzNTU3ODcz
#
# ...

# %%
frames = [userMentors, userMentees]
result = pd.concat(frames)
result
# Out:
#                           _id            login        id  \
# 0    63bf62bc2ff787e5d7eb85ec         ewpatton   1331253
# 1    63c048eee5a00d9932c67337     tmoldovan8x8  62697631
# 2    63c048efe5a00d9932c67338           saghul    317464
# 3    63be17be443439f227312a7a           KoBeWi   2223172
# 4    63be17be443439f227312a7b          Calinou    180032
# ..                        ...              ...       ...
# 256  63b3a2813583662c28eeb944    preetvadaliya  80121827
# 257  63b3a2813583662c28eeb944    preetvadaliya  80121827
# 258  63b38a3e56adab3ffd7680ba   techiepriyansh  26199781
# 259  63bfbc37be4bec0503c05389  ItsAdityaKSingh  69353350
# 260  63bfbc37be4bec0503c05389  ItsAdityaKSingh  69353350
#
#                   node_id                                         avatar_url  \
# 0    MDQ6VXNlcjEzMzEyNTM=  https://avatars.githubusercontent.com/u/133125...
# 1    MDQ6VXNlcjYyNjk3NjMx  https://avatars.githubusercontent.com/u/626976...
# ...

# %%
#total number of successful users was 285 (including mentors and mentees)
#following gives a sample of 285 (all) successful users and 285 unsuccessful users
new_df = result.groupby('Success').sample(n=285) 
new_df.to_csv('/Users/akshajsrinivasan/Desktop/dd.csv')
new_df
# Out:
#                           _id            login        id  \
# 36   63b3af72947f85c931425514         razetime  11015319
# 10   63bcc97cd14a94c738dca072          fhuzero  37891485
# 294  63bf95cfebfc0cbd2c9a8966        pdxjohnny   5950433
# 227  63bf9c35dbd8bd71d103ba46         adam2392   3460267
# 307  63bce5ebc72d9b9fcef0e143  rohityadavcloud     95203
# ..                        ...              ...       ...
# 113  63b3ac879f437484608ec73f    yogesh-sirsat  41695888
# 227  63c8e43a55244c0f6da1320f       Nosferican   2529329
# 19   63b389137d7243f3f4d51f22        jaspervdj     95501
# 309  63b4f1666676b611bf91b5d2       peterccarl   9954629
# 65   63bfadacf3022c35ad85d30d      aravindm711  29843489
#
#                   node_id                                         avatar_url  \
# 36   MDQ6VXNlcjExMDE1MzE5  https://avatars.githubusercontent.com/u/110153...
# 10   MDQ6VXNlcjM3ODkxNDg1  https://avatars.githubusercontent.com/u/378914...
# ...

# %%
#following gives a sample of 50 mentors and 50 mentees from previous sample
new_df2 = new_df.groupby('mentor').sample(n=200)
new_df2.to_excel('/Users/akshajsrinivasan/Desktop/Book1.xlsx')
